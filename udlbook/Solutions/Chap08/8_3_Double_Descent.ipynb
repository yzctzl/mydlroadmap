# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# %pip install git+https://github.com/greydanus/mnist1d

# %%
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random

random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device("cuda" if torch.cuda.is_available() else "cpu"))
print("Using:", DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale = 2e-2
data = mnist1d.data.get_dataset(
    args, path="./mnist1d_data.pkl", download=False, regenerate=True
)

# Add 15% noise to training labels
for c_y in range(len(data["y"])):
    random_number = random.random()
    if random_number < 0.15:
        random_int = int(random.random() * 10)
        data["y"][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data["y"])))
print("Examples in test set: {}".format(len(data["y_test"])))
print("Dimensionality of each example: {}".format(data["x"].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
    if isinstance(layer_in, nn.Linear):
        nn.init.kaiming_uniform_(layer_in.weight)
        layer_in.bias.data.fill_(0.0)


# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):
    D_i = 40  # Input dimensions
    D_k = n_hidden  # Hidden dimensions
    D_o = 10  # Output dimensions

    # Define a model with two hidden layers
    # And ReLU activations between them
    model = nn.Sequential(
        nn.Linear(D_i, D_k),
        nn.ReLU(),
        nn.Linear(D_k, D_k),
        nn.ReLU(),
        nn.Linear(D_k, D_o),
    )

    # Call the function you just defined
    model.apply(weights_init)

    # Return the model
    return model

# %%
def fit_model(model, data, n_epoch):
    # choose cross entropy loss function (equation 5.24)
    loss_function = torch.nn.CrossEntropyLoss()
    # construct SGD optimizer and initialize learning rate and momentum
    # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    optimizer = torch.optim.SGD(model.parameters(), lr=0.01, momentum=0.9)

    x_train = torch.tensor(data["x"].astype("float32"))
    y_train = torch.tensor(data["y"].transpose().astype("long"))
    x_test = torch.tensor(data["x_test"].astype("float32"))
    y_test = torch.tensor(data["y_test"].astype("long"))

    # load the data into a class that creates the batches
    data_loader = DataLoader(
        TensorDataset(x_train, y_train),
        batch_size=100,
        shuffle=True,
        worker_init_fn=np.random.seed(1),
    )

    for epoch in range(n_epoch):
        # loop over batches
        for i, batch in enumerate(data_loader):
            # retrieve inputs and labels for this batch
            x_batch, y_batch = batch
            # zero the parameter gradients
            optimizer.zero_grad()
            # forward pass -- calculate model output
            pred = model(x_batch)
            # compute the loss
            loss = loss_function(pred, y_batch)
            # backward pass
            loss.backward()
            # SGD update
            optimizer.step()

        # Run whole dataset to get statistics -- normally wouldn't do this
        pred_train = model(x_train)
        pred_test = model(x_test)
        _, predicted_train_class = torch.max(pred_train.data, 1)
        _, predicted_test_class = torch.max(pred_test.data, 1)
        errors_train = 100 - 100 * (
            predicted_train_class == y_train
        ).float().sum() / len(y_train)
        errors_test = 100 - 100 * (predicted_test_class == y_test).float().sum() / len(
            y_test
        )
        losses_train = loss_function(pred_train, y_train).item()
        losses_test = loss_function(pred_test, y_test).item()
        if epoch % 100 == 0:
            print(
                f"Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}"
            )

    return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TO DO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array(
    [
        2,
        4,
        6,
        8,
        10,
        14,
        18,
        22,
        26,
        30,
        35,
        40,
        45,
        50,
        55,
        60,
        70,
        80,
        90,
        100,
        120,
        140,
        160,
        180,
        200,
        250,
        300,
        400,
    ]
)
errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f"Training model with {hidden_variables[c_hidden]:3d} hidden variables")
    # Get a model
    model = get_model(hidden_variables[c_hidden])
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden] = errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.301077, train error 89.18,  test loss 2.303060, test error 89.82
# Epoch   100, train loss 1.918593, train error 72.53,  test loss 1.780669, test error 70.88
# Epoch   200, train loss 1.905097, train error 71.57,  test loss 1.768263, test error 69.60
# Epoch   300, train loss 1.899231, train error 71.22,  test loss 1.748717, test error 70.18
# Epoch   400, train loss 1.899548, train error 71.97,  test loss 1.751709, test error 69.65
# Epoch   500, train loss 1.917192, train error 72.00,  test loss 1.789764, test error 71.38
# Epoch   600, train loss 1.897064, train error 71.93,  test loss 1.735614, test error 69.80
# Epoch   700, train loss 1.898261, train error 71.15,  test loss 1.743060, test error 69.82
# Epoch   800, train loss 1.895718, train error 71.55,  test loss 1.749083, test error 69.57
# Epoch   900, train loss 1.895570, train error 71.07,  test loss 1.741823, test error 70.43
# Training model with   4 hidden variables
# Epoch     0, train loss 2.287965, train error 85.75,  test loss 2.272149, test error 86.40
# Epoch   100, train loss 1.849530, train error 69.20,  test loss 1.699366, test error 67.12
# Epoch   200, train loss 1.827788, train error 68.00,  test loss 1.697160, test error 66.72
# Epoch   300, train loss 1.798115, train error 66.28,  test loss 1.653804, test error 63.20
# Epoch   400, train loss 1.767526, train error 63.65,  test loss 1.633433, test error 61.88
# Epoch   500, train loss 1.751117, train error 62.85,  test loss 1.633709, test error 62.12
# Epoch   600, train loss 1.747150, train error 62.83,  test loss 1.642067, test error 62.53
# Epoch   700, train loss 1.742650, train error 62.47,  test loss 1.633080, test error 62.17
# Epoch   800, train loss 1.748631, train error 62.83,  test loss 1.617536, test error 62.17
# Epoch   900, train loss 1.739929, train error 62.92,  test loss 1.634458, test error 62.10
# Training model with   6 hidden variables
# Epoch     0, train loss 2.286773, train error 88.05,  test loss 2.278491, test error 88.62
# Epoch   100, train loss 1.698877, train error 60.45,  test loss 1.533859, test error 58.60
# Epoch   200, train loss 1.658014, train error 59.92,  test loss 1.506826, test error 57.67
# Epoch   300, train loss 1.649278, train error 59.25,  test loss 1.491366, test error 58.12
# Epoch   400, train loss 1.641809, train error 58.83,  test loss 1.491283, test error 57.03
# Epoch   500, train loss 1.640009, train error 58.95,  test loss 1.491319, test error 57.42
# Epoch   600, train loss 1.636536, train error 58.35,  test loss 1.500982, test error 56.95
# Epoch   700, train loss 1.643644, train error 58.55,  test loss 1.512122, test error 58.10
# Epoch   800, train loss 1.639682, train error 58.80,  test loss 1.491250, test error 57.45
# Epoch   900, train loss 1.635826, train error 58.55,  test loss 1.504140, test error 57.83
# Training model with   8 hidden variables
# Epoch     0, train loss 2.163845, train error 81.35,  test loss 2.126413, test error 79.68
# Epoch   100, train loss 1.625995, train error 57.67,  test loss 1.487819, test error 56.08
# Epoch   200, train loss 1.556703, train error 54.72,  test loss 1.409484, test error 51.85
# Epoch   300, train loss 1.530188, train error 52.92,  test loss 1.372288, test error 50.40
# Epoch   400, train loss 1.525332, train error 52.97,  test loss 1.374933, test error 50.25
# Epoch   500, train loss 1.520803, train error 53.03,  test loss 1.373858, test error 49.40
# Epoch   600, train loss 1.517909, train error 52.85,  test loss 1.372692, test error 50.35
# Epoch   700, train loss 1.502691, train error 51.90,  test loss 1.346091, test error 49.38
# Epoch   800, train loss 1.493510, train error 51.22,  test loss 1.347822, test error 50.15
# Epoch   900, train loss 1.478032, train error 50.47,  test loss 1.338781, test error 48.92
# Training model with  10 hidden variables
# Epoch     0, train loss 2.233157, train error 85.05,  test loss 2.223048, test error 84.57
# Epoch   100, train loss 1.533085, train error 52.80,  test loss 1.406301, test error 53.75
# Epoch   200, train loss 1.455724, train error 48.85,  test loss 1.321835, test error 49.00
# Epoch   300, train loss 1.423452, train error 48.15,  test loss 1.294343, test error 48.58
# Epoch   400, train loss 1.407672, train error 46.97,  test loss 1.304693, test error 48.22
# Epoch   500, train loss 1.398678, train error 47.03,  test loss 1.316789, test error 47.75
# Epoch   600, train loss 1.382834, train error 46.25,  test loss 1.313802, test error 47.83
# Epoch   700, train loss 1.378243, train error 46.25,  test loss 1.333429, test error 48.00
# Epoch   800, train loss 1.372487, train error 46.03,  test loss 1.332889, test error 47.75
# Epoch   900, train loss 1.375520, train error 45.85,  test loss 1.347171, test error 48.45
# Training model with  14 hidden variables
# Epoch     0, train loss 2.249773, train error 84.18,  test loss 2.239886, test error 84.43
# Epoch   100, train loss 1.516703, train error 51.58,  test loss 1.416331, test error 55.47
# Epoch   200, train loss 1.420763, train error 47.40,  test loss 1.391264, test error 53.08
# Epoch   300, train loss 1.364401, train error 45.97,  test loss 1.369498, test error 51.80
# Epoch   400, train loss 1.334280, train error 45.72,  test loss 1.402404, test error 52.83
# Epoch   500, train loss 1.320654, train error 45.35,  test loss 1.405678, test error 52.95
# Epoch   600, train loss 1.320341, train error 45.83,  test loss 1.427272, test error 53.85
# Epoch   700, train loss 1.305515, train error 44.60,  test loss 1.422850, test error 53.00
# Epoch   800, train loss 1.318533, train error 44.45,  test loss 1.444045, test error 53.80
# Epoch   900, train loss 1.301079, train error 44.30,  test loss 1.425667, test error 53.53
# Training model with  18 hidden variables
# Epoch     0, train loss 2.157223, train error 80.60,  test loss 2.142821, test error 79.78
# Epoch   100, train loss 1.379184, train error 46.47,  test loss 1.327099, test error 49.58
# Epoch   200, train loss 1.281891, train error 43.62,  test loss 1.302850, test error 48.60
# Epoch   300, train loss 1.232149, train error 41.33,  test loss 1.333161, test error 48.38
# Epoch   400, train loss 1.193510, train error 40.53,  test loss 1.378816, test error 49.15
# Epoch   500, train loss 1.170318, train error 39.33,  test loss 1.401459, test error 49.08
# Epoch   600, train loss 1.155401, train error 39.20,  test loss 1.441985, test error 49.35
# Epoch   700, train loss 1.144737, train error 38.80,  test loss 1.485268, test error 50.00
# Epoch   800, train loss 1.130629, train error 38.03,  test loss 1.532344, test error 50.72
# Epoch   900, train loss 1.128645, train error 37.97,  test loss 1.558252, test error 50.58
# Training model with  22 hidden variables
# Epoch     0, train loss 2.134650, train error 79.60,  test loss 2.097766, test error 78.15
# Epoch   100, train loss 1.222585, train error 40.05,  test loss 1.272274, test error 46.33
# Epoch   200, train loss 1.118375, train error 37.78,  test loss 1.344825, test error 48.00
# Epoch   300, train loss 1.051881, train error 34.72,  test loss 1.416472, test error 48.42
# Epoch   400, train loss 1.031299, train error 34.75,  test loss 1.494974, test error 49.17
# Epoch   500, train loss 0.996709, train error 33.00,  test loss 1.575953, test error 49.97
# Epoch   600, train loss 0.995865, train error 34.00,  test loss 1.656707, test error 50.75
# Epoch   700, train loss 0.974451, train error 31.85,  test loss 1.671796, test error 50.47
# Epoch   800, train loss 0.950023, train error 31.60,  test loss 1.705487, test error 50.40
# Epoch   900, train loss 0.954331, train error 31.38,  test loss 1.733889, test error 50.88
# Training model with  26 hidden variables
# Epoch     0, train loss 2.150863, train error 80.20,  test loss 2.129427, test error 79.80
# Epoch   100, train loss 1.196783, train error 38.88,  test loss 1.263983, test error 46.90
# Epoch   200, train loss 1.036854, train error 33.72,  test loss 1.345941, test error 47.70
# Epoch   300, train loss 0.963044, train error 31.38,  test loss 1.466566, test error 49.75
# Epoch   400, train loss 0.915725, train error 29.82,  test loss 1.550486, test error 49.85
# Epoch   500, train loss 0.895269, train error 29.90,  test loss 1.649033, test error 50.85
# Epoch   600, train loss 0.861645, train error 29.03,  test loss 1.710077, test error 51.50
# Epoch   700, train loss 0.836646, train error 27.62,  test loss 1.798698, test error 51.95
# Epoch   800, train loss 0.813693, train error 27.50,  test loss 1.887208, test error 52.90
# Epoch   900, train loss 0.806988, train error 27.07,  test loss 1.986251, test error 52.50
# Training model with  30 hidden variables
# Epoch     0, train loss 2.114761, train error 78.40,  test loss 2.085327, test error 77.25
# Epoch   100, train loss 1.146092, train error 37.95,  test loss 1.367369, test error 49.25
# Epoch   200, train loss 0.934594, train error 30.75,  test loss 1.500209, test error 49.35
# Epoch   300, train loss 0.853078, train error 28.68,  test loss 1.699214, test error 51.25
# Epoch   400, train loss 0.787987, train error 26.30,  test loss 1.869819, test error 53.00
# Epoch   500, train loss 0.756673, train error 25.38,  test loss 2.037324, test error 53.85
# Epoch   600, train loss 0.728980, train error 24.88,  test loss 2.214041, test error 54.90
# Epoch   700, train loss 0.713807, train error 25.30,  test loss 2.357616, test error 54.65
# Epoch   800, train loss 0.696126, train error 23.95,  test loss 2.468874, test error 55.15
# Epoch   900, train loss 0.668871, train error 23.57,  test loss 2.582777, test error 55.97
# Training model with  35 hidden variables
# Epoch     0, train loss 2.178440, train error 79.68,  test loss 2.141794, test error 78.55
# Epoch   100, train loss 1.021040, train error 34.07,  test loss 1.362069, test error 49.15
# Epoch   200, train loss 0.787069, train error 26.65,  test loss 1.663870, test error 51.15
# Epoch   300, train loss 0.660594, train error 21.65,  test loss 2.037510, test error 53.15
# Epoch   400, train loss 0.598509, train error 19.68,  test loss 2.434270, test error 54.78
# Epoch   500, train loss 0.552583, train error 18.18,  test loss 2.780884, test error 54.97
# Epoch   600, train loss 0.518233, train error 17.90,  test loss 3.036992, test error 55.40
# Epoch   700, train loss 0.514742, train error 17.90,  test loss 3.320372, test error 56.80
# Epoch   800, train loss 0.491835, train error 16.47,  test loss 3.529216, test error 55.45
# Epoch   900, train loss 0.474272, train error 16.05,  test loss 3.727269, test error 55.47
# Training model with  40 hidden variables
# Epoch     0, train loss 2.097299, train error 78.78,  test loss 2.065764, test error 77.68
# Epoch   100, train loss 0.904658, train error 29.40,  test loss 1.472017, test error 51.10
# Epoch   200, train loss 0.634933, train error 20.85,  test loss 1.966211, test error 51.45
# Epoch   300, train loss 0.487698, train error 15.82,  test loss 2.565820, test error 53.50
# Epoch   400, train loss 0.375635, train error 11.93,  test loss 3.209292, test error 53.88
# Epoch   500, train loss 0.372696, train error 12.78,  test loss 4.025066, test error 55.08
# Epoch   600, train loss 0.292065, train error 10.18,  test loss 4.746593, test error 54.92
# Epoch   700, train loss 0.272216, train error 9.70,  test loss 5.538873, test error 56.65
# Epoch   800, train loss 0.227144, train error 7.70,  test loss 6.110096, test error 55.92
# Epoch   900, train loss 0.242680, train error 8.20,  test loss 6.757521, test error 56.58
# Training model with  45 hidden variables
# Epoch     0, train loss 2.091561, train error 77.78,  test loss 2.058104, test error 78.05
# Epoch   100, train loss 0.842795, train error 27.15,  test loss 1.596763, test error 53.38
# Epoch   200, train loss 0.498721, train error 14.78,  test loss 2.372780, test error 55.35
# Epoch   300, train loss 0.330308, train error 10.12,  test loss 3.521606, test error 55.62
# Epoch   400, train loss 0.213630, train error 6.55,  test loss 4.827868, test error 56.95
# Epoch   500, train loss 0.196877, train error 7.03,  test loss 6.264262, test error 58.47
# Epoch   600, train loss 0.189481, train error 6.60,  test loss 7.468839, test error 58.15
# Epoch   700, train loss 0.018033, train error 0.00,  test loss 8.535843, test error 58.17
# Epoch   800, train loss 0.009891, train error 0.00,  test loss 9.423162, test error 58.05
# Epoch   900, train loss 0.007066, train error 0.00,  test loss 10.023922, test error 58.08
# Training model with  50 hidden variables
# Epoch     0, train loss 2.082622, train error 75.70,  test loss 2.047503, test error 76.53
# Epoch   100, train loss 0.734557, train error 22.40,  test loss 1.613335, test error 50.15
# Epoch   200, train loss 0.372902, train error 10.88,  test loss 2.660043, test error 53.45
# Epoch   300, train loss 0.174722, train error 4.53,  test loss 4.162701, test error 55.47
# Epoch   400, train loss 0.038910, train error 0.10,  test loss 6.008125, test error 56.70
# Epoch   500, train loss 0.013880, train error 0.00,  test loss 7.109206, test error 57.03
# Epoch   600, train loss 0.008541, train error 0.00,  test loss 7.812308, test error 57.38
# Epoch   700, train loss 0.006020, train error 0.00,  test loss 8.325143, test error 57.65
# Epoch   800, train loss 0.004626, train error 0.00,  test loss 8.735946, test error 57.58
# Epoch   900, train loss 0.003713, train error 0.00,  test loss 9.080485, test error 57.67
# Training model with  55 hidden variables
# Epoch     0, train loss 2.068016, train error 76.15,  test loss 2.010221, test error 76.18
# Epoch   100, train loss 0.621893, train error 17.90,  test loss 1.612989, test error 50.15
# Epoch   200, train loss 0.197498, train error 4.45,  test loss 2.952626, test error 52.47
# Epoch   300, train loss 0.041481, train error 0.07,  test loss 4.572515, test error 53.00
# Epoch   400, train loss 0.013990, train error 0.00,  test loss 5.553724, test error 53.20
# Epoch   500, train loss 0.008076, train error 0.00,  test loss 6.139320, test error 53.60
# Epoch   600, train loss 0.005606, train error 0.00,  test loss 6.561497, test error 53.55
# Epoch   700, train loss 0.004187, train error 0.00,  test loss 6.892456, test error 53.50
# Epoch   800, train loss 0.003310, train error 0.00,  test loss 7.165167, test error 53.58
# Epoch   900, train loss 0.002725, train error 0.00,  test loss 7.392602, test error 53.78
# Training model with  60 hidden variables
# Epoch     0, train loss 2.095649, train error 77.68,  test loss 2.066992, test error 76.45
# Epoch   100, train loss 0.503595, train error 14.47,  test loss 1.730210, test error 49.65
# Epoch   200, train loss 0.111875, train error 1.62,  test loss 3.371075, test error 53.58
# Epoch   300, train loss 0.020565, train error 0.00,  test loss 4.654674, test error 53.42
# Epoch   400, train loss 0.009651, train error 0.00,  test loss 5.343995, test error 53.42
# Epoch   500, train loss 0.006086, train error 0.00,  test loss 5.802325, test error 53.50
# Epoch   600, train loss 0.004310, train error 0.00,  test loss 6.130604, test error 53.42
# Epoch   700, train loss 0.003310, train error 0.00,  test loss 6.395142, test error 53.42
# Epoch   800, train loss 0.002657, train error 0.00,  test loss 6.608515, test error 53.40
# Epoch   900, train loss 0.002202, train error 0.00,  test loss 6.796288, test error 53.45
# Training model with  70 hidden variables
# Epoch     0, train loss 2.038396, train error 75.10,  test loss 1.988737, test error 75.28
# Epoch   100, train loss 0.391551, train error 9.75,  test loss 1.936944, test error 51.33
# Epoch   200, train loss 0.036823, train error 0.00,  test loss 3.631858, test error 53.85
# Epoch   300, train loss 0.011415, train error 0.00,  test loss 4.509993, test error 54.08
# Epoch   400, train loss 0.006321, train error 0.00,  test loss 4.982770, test error 54.25
# Epoch   500, train loss 0.004206, train error 0.00,  test loss 5.316177, test error 54.30
# Epoch   600, train loss 0.003107, train error 0.00,  test loss 5.566572, test error 54.03
# Epoch   700, train loss 0.002441, train error 0.00,  test loss 5.767300, test error 54.10
# Epoch   800, train loss 0.001986, train error 0.00,  test loss 5.937134, test error 54.17
# Epoch   900, train loss 0.001672, train error 0.00,  test loss 6.080975, test error 54.03
# Training model with  80 hidden variables
# Epoch     0, train loss 2.034895, train error 76.70,  test loss 1.990411, test error 76.45
# Epoch   100, train loss 0.261449, train error 5.65,  test loss 2.089161, test error 52.40
# Epoch   200, train loss 0.020796, train error 0.00,  test loss 3.433131, test error 52.97
# Epoch   300, train loss 0.008250, train error 0.00,  test loss 3.992015, test error 53.12
# Epoch   400, train loss 0.004848, train error 0.00,  test loss 4.321845, test error 52.95
# Epoch   500, train loss 0.003354, train error 0.00,  test loss 4.558581, test error 53.08
# Epoch   600, train loss 0.002526, train error 0.00,  test loss 4.742305, test error 53.28
# Epoch   700, train loss 0.001996, train error 0.00,  test loss 4.891644, test error 53.30
# Epoch   800, train loss 0.001642, train error 0.00,  test loss 5.016079, test error 53.35
# Epoch   900, train loss 0.001388, train error 0.00,  test loss 5.124116, test error 53.42
# Training model with  90 hidden variables
# Epoch     0, train loss 1.997500, train error 74.50,  test loss 1.937601, test error 74.75
# Epoch   100, train loss 0.168156, train error 1.65,  test loss 2.177910, test error 51.72
# Epoch   200, train loss 0.015782, train error 0.00,  test loss 3.257610, test error 52.47
# Epoch   300, train loss 0.006756, train error 0.00,  test loss 3.699210, test error 52.35
# Epoch   400, train loss 0.004102, train error 0.00,  test loss 3.963530, test error 52.08
# Epoch   500, train loss 0.002866, train error 0.00,  test loss 4.159172, test error 52.10
# Epoch   600, train loss 0.002174, train error 0.00,  test loss 4.310109, test error 51.95
# Epoch   700, train loss 0.001736, train error 0.00,  test loss 4.432252, test error 52.03
# Epoch   800, train loss 0.001435, train error 0.00,  test loss 4.537578, test error 52.10
# Epoch   900, train loss 0.001216, train error 0.00,  test loss 4.626440, test error 52.10
# Training model with 100 hidden variables
# Epoch     0, train loss 2.007045, train error 75.00,  test loss 1.938909, test error 74.50
# Epoch   100, train loss 0.094017, train error 0.12,  test loss 2.222389, test error 51.90
# Epoch   200, train loss 0.012462, train error 0.00,  test loss 3.073963, test error 51.38
# Epoch   300, train loss 0.005763, train error 0.00,  test loss 3.436622, test error 51.35
# Epoch   400, train loss 0.003593, train error 0.00,  test loss 3.665848, test error 51.35
# Epoch   500, train loss 0.002552, train error 0.00,  test loss 3.829841, test error 51.47
# Epoch   600, train loss 0.001953, train error 0.00,  test loss 3.961775, test error 51.55
# Epoch   700, train loss 0.001570, train error 0.00,  test loss 4.069384, test error 51.67
# Epoch   800, train loss 0.001304, train error 0.00,  test loss 4.159825, test error 51.75
# Epoch   900, train loss 0.001111, train error 0.00,  test loss 4.238622, test error 51.80
# Training model with 120 hidden variables
# Epoch     0, train loss 1.976444, train error 72.93,  test loss 1.889478, test error 73.22
# Epoch   100, train loss 0.053945, train error 0.03,  test loss 2.219583, test error 50.35
# Epoch   200, train loss 0.009676, train error 0.00,  test loss 2.839031, test error 50.28
# Epoch   300, train loss 0.004757, train error 0.00,  test loss 3.119643, test error 50.00
# Epoch   400, train loss 0.003032, train error 0.00,  test loss 3.301114, test error 49.97
# Epoch   500, train loss 0.002181, train error 0.00,  test loss 3.434490, test error 50.05
# Epoch   600, train loss 0.001685, train error 0.00,  test loss 3.537318, test error 50.10
# Epoch   700, train loss 0.001362, train error 0.00,  test loss 3.624193, test error 50.15
# Epoch   800, train loss 0.001136, train error 0.00,  test loss 3.697326, test error 50.08
# Epoch   900, train loss 0.000971, train error 0.00,  test loss 3.761625, test error 50.00
# Training model with 140 hidden variables
# Epoch     0, train loss 1.948583, train error 72.45,  test loss 1.872147, test error 72.60
# Epoch   100, train loss 0.038677, train error 0.00,  test loss 2.171553, test error 50.25
# Epoch   200, train loss 0.008213, train error 0.00,  test loss 2.644064, test error 49.78
# Epoch   300, train loss 0.004177, train error 0.00,  test loss 2.868835, test error 49.90
# Epoch   400, train loss 0.002709, train error 0.00,  test loss 3.019922, test error 49.90
# Epoch   500, train loss 0.001971, train error 0.00,  test loss 3.129716, test error 50.00
# Epoch   600, train loss 0.001530, train error 0.00,  test loss 3.217946, test error 50.20
# Epoch   700, train loss 0.001241, train error 0.00,  test loss 3.290343, test error 50.17
# Epoch   800, train loss 0.001039, train error 0.00,  test loss 3.352855, test error 50.30
# Epoch   900, train loss 0.000890, train error 0.00,  test loss 3.407020, test error 50.30
# Training model with 160 hidden variables
# Epoch     0, train loss 1.934875, train error 71.22,  test loss 1.857161, test error 72.72
# Epoch   100, train loss 0.027465, train error 0.00,  test loss 2.134154, test error 48.35
# Epoch   200, train loss 0.007028, train error 0.00,  test loss 2.546003, test error 48.72
# Epoch   300, train loss 0.003708, train error 0.00,  test loss 2.751225, test error 48.95
# Epoch   400, train loss 0.002437, train error 0.00,  test loss 2.885041, test error 48.72
# Epoch   500, train loss 0.001786, train error 0.00,  test loss 2.984994, test error 48.65
# Epoch   600, train loss 0.001395, train error 0.00,  test loss 3.066374, test error 48.78
# Epoch   700, train loss 0.001136, train error 0.00,  test loss 3.132610, test error 48.83
# Epoch   800, train loss 0.000953, train error 0.00,  test loss 3.189860, test error 48.88
# Epoch   900, train loss 0.000818, train error 0.00,  test loss 3.239543, test error 48.83
# Training model with 180 hidden variables
# Epoch     0, train loss 1.948731, train error 71.47,  test loss 1.883752, test error 71.90
# Epoch   100, train loss 0.024181, train error 0.00,  test loss 2.036638, test error 47.80
# Epoch   200, train loss 0.006575, train error 0.00,  test loss 2.380481, test error 48.08
# Epoch   300, train loss 0.003533, train error 0.00,  test loss 2.554907, test error 48.30
# Epoch   400, train loss 0.002336, train error 0.00,  test loss 2.672825, test error 48.42
# Epoch   500, train loss 0.001718, train error 0.00,  test loss 2.760721, test error 48.50
# Epoch   600, train loss 0.001346, train error 0.00,  test loss 2.831665, test error 48.67
# Epoch   700, train loss 0.001099, train error 0.00,  test loss 2.890978, test error 48.60
# Epoch   800, train loss 0.000924, train error 0.00,  test loss 2.941333, test error 48.60
# Epoch   900, train loss 0.000794, train error 0.00,  test loss 2.985737, test error 48.60
# Training model with 200 hidden variables
# Epoch     0, train loss 1.918136, train error 70.40,  test loss 1.822952, test error 70.28
# Epoch   100, train loss 0.021283, train error 0.00,  test loss 2.045616, test error 47.15
# Epoch   200, train loss 0.006078, train error 0.00,  test loss 2.368249, test error 47.47
# Epoch   300, train loss 0.003299, train error 0.00,  test loss 2.536548, test error 47.53
# Epoch   400, train loss 0.002202, train error 0.00,  test loss 2.648946, test error 47.47
# Epoch   500, train loss 0.001629, train error 0.00,  test loss 2.733703, test error 47.45
# Epoch   600, train loss 0.001279, train error 0.00,  test loss 2.801684, test error 47.35
# Epoch   700, train loss 0.001047, train error 0.00,  test loss 2.859033, test error 47.40
# Epoch   800, train loss 0.000882, train error 0.00,  test loss 2.907338, test error 47.40
# Epoch   900, train loss 0.000759, train error 0.00,  test loss 2.950227, test error 47.40
# Training model with 250 hidden variables
# Epoch     0, train loss 1.886393, train error 68.43,  test loss 1.811030, test error 69.65
# Epoch   100, train loss 0.016903, train error 0.00,  test loss 1.873008, test error 45.40
# Epoch   200, train loss 0.005273, train error 0.00,  test loss 2.117076, test error 45.17
# Epoch   300, train loss 0.002943, train error 0.00,  test loss 2.247716, test error 45.42
# Epoch   400, train loss 0.001991, train error 0.00,  test loss 2.336496, test error 45.60
# Epoch   500, train loss 0.001482, train error 0.00,  test loss 2.405012, test error 45.50
# Epoch   600, train loss 0.001170, train error 0.00,  test loss 2.460107, test error 45.65
# Epoch   700, train loss 0.000961, train error 0.00,  test loss 2.505163, test error 45.60
# Epoch   800, train loss 0.000812, train error 0.00,  test loss 2.545175, test error 45.58
# Epoch   900, train loss 0.000700, train error 0.00,  test loss 2.579475, test error 45.58
# Training model with 300 hidden variables
# Epoch     0, train loss 1.881191, train error 68.53,  test loss 1.831362, test error 70.22
# Epoch   100, train loss 0.014258, train error 0.00,  test loss 1.882605, test error 46.80
# Epoch   200, train loss 0.004770, train error 0.00,  test loss 2.105841, test error 46.45
# Epoch   300, train loss 0.002705, train error 0.00,  test loss 2.227722, test error 46.35
# Epoch   400, train loss 0.001842, train error 0.00,  test loss 2.312301, test error 46.42
# Epoch   500, train loss 0.001378, train error 0.00,  test loss 2.374798, test error 46.53
# Epoch   600, train loss 0.001092, train error 0.00,  test loss 2.426978, test error 46.55
# Epoch   700, train loss 0.000899, train error 0.00,  test loss 2.469949, test error 46.50
# Epoch   800, train loss 0.000761, train error 0.00,  test loss 2.507292, test error 46.47
# Epoch   900, train loss 0.000658, train error 0.00,  test loss 2.539650, test error 46.45
# Training model with 400 hidden variables
# Epoch     0, train loss 1.849780, train error 66.80,  test loss 1.778210, test error 68.40
# Epoch   100, train loss 0.011577, train error 0.00,  test loss 1.817371, test error 46.35
# Epoch   200, train loss 0.004145, train error 0.00,  test loss 2.001734, test error 46.12
# Epoch   300, train loss 0.002405, train error 0.00,  test loss 2.103368, test error 46.12
# Epoch   400, train loss 0.001657, train error 0.00,  test loss 2.173384, test error 46.12
# Epoch   500, train loss 0.001249, train error 0.00,  test loss 2.229004, test error 46.12
# Epoch   600, train loss 0.000994, train error 0.00,  test loss 2.273023, test error 46.03
# Epoch   700, train loss 0.000822, train error 0.00,  test loss 2.310262, test error 46.05
# Epoch   800, train loss 0.000698, train error 0.00,  test loss 2.342484, test error 46.03
# Epoch   900, train loss 0.000604, train error 0.00,  test loss 2.370919, test error 46.12

# %%
# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data["y"])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, "r-", label="train")
ax.plot(hidden_variables, errors_test_all, "b-", label="test")

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(
    x=hidden_variable_at_num_training_examples,
    color="g",
    linestyle="--",
    label="N(weights) = N(train)",
)

ax.set_ylim(0, 100)
ax.set_xlabel("No. hidden variables")
ax.set_ylabel("Error")
ax.legend()
plt.show()
